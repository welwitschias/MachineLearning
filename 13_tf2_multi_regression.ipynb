# %%
import numpy as np

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

# %%
# dataset 생성
x_data = np.array([[1, 2, 0], [5, 4, 3], [1, 2, -1], [3, 1, 0], [2, 4, 2],
                   [4, 1, 2], [-1, 3, 2], [4, 3, 3], [0, 2, 6], [2, 2, 1],
                   [1, -2, -2], [0, 1, 3], [1, 1, 3], [0, 1, 4], [2, 3, 3]])
t_data = np.array([-4, 4, -6, 3, -4,
                   9, -7, 5, 6, 0,
                   4, 3, 5, 5, 1])

# model 구축
model = Sequential()
model.add(Dense(1, input_shape=(3,), activation='linear'))

# model compile 및 summary
model.compile(optimizer=SGD(learning_rate=1e-2), loss='mse')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 4
#
# ...
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model 학습
hist = model.fit(x_data, t_data, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 212ms/step - loss: 64.6821
# Epoch 2/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 39.3286
# Epoch 3/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 26.4448
# Epoch 4/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 19.7354
# Epoch 5/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 16.0924
# Epoch 6/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 13.9804
# Epoch 7/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 12.6408
# Epoch 8/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 11.6981
# Epoch 9/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 10.9660
# Epoch 10/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 10.3517
# Epoch 11/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 9.8085
# Epoch 12/1000
# ...

# %%
# model 사용
result = model.predict(np.array([[5, 5, 0], [2, 3, 1]]))
print(result)
# Out:
# 1/1 [==============================] - 0s 61ms/step
# [[-5.0008073]
#  [-2.9997692]]
